# %% [markdown]
# ## Imports #

# %%
from forecast_flag import *

# %% [markdown]
# ## Data Generation for Unfolding aggregated data##

# %%
mplnTable,mpInProduct,mpInLocation,mpInCustomer,mpInDistrChannel = generate_input(100)

# %%
mplnTable
# Out:
#     product_lvl_id  location_lvl_id  customer_lvl_id  distr_channel_lvl_id
# 0            10000            10000            10000                 10000
# 1            10001            10001            10001                 10001
# 2            10002            10002            10002                 10002
# 3            10003            10003            10003                 10003
# 4            10004            10004            10004                 10004
# ..             ...              ...              ...                   ...
# 95           10095            10095            10095                 10095
# 96           10096            10096            10096                 10096
# 97           10097            10097            10097                 10097
# 98           10098            10098            10098                 10098
# 99           10099            10099            10099                 10099
#
# [100 rows x 4 columns]

# %%
mpInCustomer
# Out:
#     customer_lvl_id  location_lvl_desc5  location_id  location_nm  \
# 0             10000               10000        10000        10000
# 1             10001               10001        10001        10001
# 2             10002               10002        10002        10002
# 3             10003               10003        10003        10003
# 4             10004               10004        10004        10004
# ..              ...                 ...          ...          ...
# 95            10095               10095        10095        10095
# 96            10096               10096        10096        10096
# 97            10097               10097        10097        10097
# 98            10098               10098        10098        10098
# 99            10099               10099        10099        10099
#
#     location_desc  open_dttm  close_dttm  modified_dttm  del_flag
# 0           10000      10000       10000          10000         1
# ...

# %%
unfold_aggregated_data(mplnTable,mpInProduct,mpInLocation,mpInCustomer,mpInDistrChannel)
# Out:
#     product_lvl_id  location_lvl_id  customer_lvl_id  distr_channel_lvl_id  \
# 0            10000            10000            10000                 10000
# 1            10001            10001            10001                 10001
# 2            10002            10002            10002                 10002
# 3            10003            10003            10003                 10003
# 4            10004            10004            10004                 10004
# ..             ...              ...              ...                   ...
# 95           10095            10095            10095                 10095
# 96           10096            10096            10096                 10096
# 97           10097            10097            10097                 10097
# 98           10098            10098            10098                 10098
# 99           10099            10099            10099                 10099
#
# ...

# %% [markdown]
# ## Generating input for incremental load preparation##

# %%
sales, stock, sell_in, sell_out, ASSORT_MATRIX, LOCATION_LIFE = generate_input_ilp('2002-12-01','2003-12-01')
# Out:
# /content/forecast_flag.py:186: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   LOCATION_LIFE.PERIOD_TYPE = pd.Series(np.random.choice(['reconstruction','re-branding'],size))
# /content/forecast_flag.py:187: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   LOCATION_LIFE.del_flag = pd.Series(np.random.choice([0,1],size))

# %%
sales
# Out:
#      period_dt  product_id  location_id  customer_id  distr_channel_id  \
# 0   2002-12-01       10000        10000        10000             10000
# 1   2002-12-02       10001        10001        10001             10001
# 2   2002-12-03       10002        10002        10002             10002
# 3   2002-12-04       10003        10003        10003             10003
# 4   2002-12-05       10004        10004        10004             10004
# ..         ...         ...          ...          ...               ...
# 361 2003-11-27       10361        10361        10361             10361
# 362 2003-11-28       10362        10362        10362             10362
# 363 2003-11-29       10363        10363        10363             10363
# 364 2003-11-30       10364        10364        10364             10364
# 365 2003-12-01       10365        10365        10365             10365
#
#      period_start_dt
# 0              10000
# 1              10001
# 2              10002
# 3              10003
# ...

# %% [markdown]
# ## Incremental load preparation ##

# %%
QUADRUPLES_DELETE, ASSORT_MATRIX_UPDATE_FF = incremental_load_preparation(sales, stock, sell_in, sell_out, ASSORT_MATRIX, LOCATION_LIFE,'2002-12-01','2003-12-01')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:44: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:46: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
