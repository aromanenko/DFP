# %% [markdown]
# ## Importing ##

# %%
from assembling import *

# %% [markdown]
# ## Input data Generation ##

# %%
data = generate_data('2002-12-1','2022-06-05')

# %%
data
# Out:
#            date SEGMENT_NAME  HYBRID_FORECAST_VALUE  CUSTOMER_LVL_ID1  \
# 0    2002-12-01   Low Volume               0.405073            928845
# 1    2002-12-02   Low Volume               0.074648            917788
# 2    2002-12-03   Low Volume               0.057117            926685
# 3    2002-12-04      Retired               0.800762            919984
# 4    2002-12-05   Low Volume               1.810381            962662
# ...         ...          ...                    ...               ...
# 7122 2022-06-01      Retired               1.928949            951021
# 7123 2022-06-02        Short               0.699601            939587
# 7124 2022-06-03        Short               0.251907            978303
# 7125 2022-06-04   Low Volume               0.554015            970922
# 7126 2022-06-05        Short               1.015516            967434
#
#       DISTR_CHANNEL_LVL_ID  VF_FORECAST_VALUE  ML_FORECAST_VALUE  \
# ...

# %%
data
# Out:
#            date SEGMENT_NAME  HYBRID_FORECAST_VALUE  CUSTOMER_LVL_ID1  \
# 0    2002-12-01   Low Volume               0.405073            928845
# 1    2002-12-02   Low Volume               0.074648            917788
# 2    2002-12-03   Low Volume               0.057117            926685
# 3    2002-12-04      Retired               0.800762            919984
# 4    2002-12-05   Low Volume               1.810381            962662
# ...         ...          ...                    ...               ...
# 7122 2022-06-01      Retired               1.928949            951021
# 7123 2022-06-02        Short               0.699601            939587
# 7124 2022-06-03        Short               0.251907            978303
# 7125 2022-06-04   Low Volume               0.554015            970922
# 7126 2022-06-05        Short               1.015516            967434
#
#       DISTR_CHANNEL_LVL_ID  VF_FORECAST_VALUE  ML_FORECAST_VALUE  \
# ...

# %% [markdown]
# ## Assembling Algorithm Output ##

# %%
hybridization(data)
# Out:
#            date SEGMENT_NAME  HYBRID_FORECAST_VALUE  CUSTOMER_LVL_ID1  \
# 0    2002-12-01   Low Volume               0.001000            928845
# 1    2002-12-02   Low Volume               0.600605            917788
# 2    2002-12-03   Low Volume               0.409552            926685
# 3    2002-12-04      Retired               0.776989            919984
# 4    2002-12-05   Low Volume               0.992910            962662
# ...         ...          ...                    ...               ...
# 7122 2022-06-01      Retired               0.001000            951021
# 7123 2022-06-02        Short               1.329466            939587
# 7124 2022-06-03        Short               0.086105            978303
# 7125 2022-06-04   Low Volume               0.148942            970922
# 7126 2022-06-05        Short               0.447884            967434
#
#       DISTR_CHANNEL_LVL_ID  VF_FORECAST_VALUE  ML_FORECAST_VALUE  \
# ...
