# %%
from reconcilation import *

# %% [markdown]
# ## Reading input files

# %%
PRODUCT = pd.read_csv('DPS_PRODUCT.csv')
LOCATION = pd.read_csv('DPS_LOCATION.csv')
CUSTOMER = pd.read_csv('DPS_CUSTOMER.csv')
DISTR_CHANNEL = pd.read_csv('DPS_DISTR_CHANNEL.csv')

PRODUCT.columns = PRODUCT.columns.str.lower()
LOCATION.columns = LOCATION.columns.str.lower()
CUSTOMER.columns = CUSTOMER.columns.str.lower()
DISTR_CHANNEL.columns = DISTR_CHANNEL.columns.str.lower()

hierarchies = {
    'product' : PRODUCT,
    'location' : LOCATION,
    'customer' : CUSTOMER,
    'distr_channel' : DISTR_CHANNEL
}

# %% [markdown]
# ## Config example

# %%
config = {
    'tgt_type' : 'POS',
    'value_src' : 'SALES_QTY',
    'act_flag' : 1,
    'vf_product_lvl' : 1,
    'vf_location_lvl' : 1,
    'vf_customer_lvl' : 1,
    'vf_distr_channel_lvl' : 1,
    'vf_time_lvl' : 'MONTH',
    'ml_product_lvl' : 7,
    'ml_location_lvl' : 5,
    'ml_customer_lvl' : 5,
    'ml_distr_channel_lvl' : 1,
    'ml_time_lvl' : 'WEEK'
}

IB_HIST_END_DT = datetime.datetime(2022, 6, 30)
IB_FC_HORIZ = 30

# %% [markdown]
# ## Generating data

# %%
VF_FORECAST, ML_FORECAST = generate_data(config, IB_HIST_END_DT, hierarchies)

# %%
VF_FORECAST.head()
# Out:
#    PERIOD_DT  product_lvl_id1  customer_lvl_id1  location_lvl_id1  \
# 0 2022-07-01            10084           1000000            100000
# 1 2022-08-01            10084           1000000            100000
# 2 2022-09-01            10084           1000000            100000
# 3 2022-10-01            10084           1000000            100000
# 4 2022-11-01            10084           1000000            100000
#
#    distr_channel_lvl_id1  FORECAST_VALUE
# 0                      2      774.494503
# 1                      2      334.073194
# 2                      2      744.781974
# 3                      2      816.965498
# 4                      2      222.958516

# %%
ML_FORECAST.head()
# Out:
#    PERIOD_DT  product_lvl_id7  customer_lvl_id5  location_lvl_id5  \
# 0 2022-07-04            70001           5000001            500015
# 1 2022-07-04            70001           5000001            500015
# 2 2022-07-04            70001           5000001            500014
# 3 2022-07-04            70001           5000001            500014
# 4 2022-07-04            70001           5000001            500015
#
#    distr_channel_lvl_id1  FORECAST_VALUE DEMAND_TYPE ASSORTMENT_TYPE
# 0                      2      633.785977     regular             old
# 1                      2      535.002304     regular             new
# 2                      2      602.919558     regular             old
# 3                      2      651.119234       promo             old
# 4                      2      617.512781     regular             new

# %% [markdown]
# ## Running the algorighm

# %%
mid_reconciled_forecast, reconciled_forecast = reconcilation_algorithm(
    VF_FORECAST, ML_FORECAST, config, IB_HIST_END_DT, IB_FC_HORIZ, hierarchies
)

# %%
mid_reconciled_forecast
# Out:
#    PERIOD_END_DT  product_lvl_id1  customer_lvl_id1  location_lvl_id1  \
# 2     2022-09-01            10084           1000000            100000
# 3     2022-10-01            10084           1000000            100000
# 4     2022-11-01            10084           1000000            100000
# 5     2022-12-01            10084           1000000            100000
# 6     2023-01-01            10084           1000000            100000
# 7     2023-02-01            10084           1000000            100000
# 8     2023-03-01            10084           1000000            100000
# 9     2023-04-01            10084           1000000            100000
# 10    2023-05-01            10084           1000000            100000
# 11    2023-06-01            10084           1000000            100000
#
#     distr_channel_lvl_id1  VF_FORECAST_VALUE_REC ML_FORECAST_VALUE  \
# 2                       2             744.781974              None
# 3                       2             816.965498              None
# 4                       2             222.958516              None
# 5                       2            1268.406247              None
# 6                       2             650.039840              None
# 7                       2              15.296610              None
# 8                       2             739.964155              None
# 9                       2             195.649832              None
# 10                      2              19.184014              None
# 11                      2             507.312632              None
#
#    DEMAND_TYPE ASSORTMENT_TYPE
# 2      Regular             old
# 3      Regular             old
# 4      Regular             old
# 5      Regular             old
# 6      Regular             old
# 7      Regular             old
# 8      Regular             old
# 9      Regular             old
# 10     Regular             old
# 11     Regular             old

# %%
reconciled_forecast
# Out:
#         product_lvl_id7  customer_lvl_id5  location_lvl_id5  \
# 0                 70001           5000001            500015
# 1                 70001           5000001            500015
# 2                 70001           5000001            500015
# 3                 70001           5000001            500015
# 4                 70001           5000001            500015
# ...                 ...               ...               ...
# 146075            70083           5000003            500017
# 146076            70083           5000003            500017
# 146077            70083           5000003            500017
# 146078            70083           5000003            500017
# 146079            70083           5000003            500017
#
#         distr_channel_lvl_id1  ML_FORECAST_VALUE DEMAND_TYPE ASSORTMENT_TYPE  \
# 0                           2         633.785977     regular             old
# 1                           2         535.002304     regular             new
# 2                           2         617.512781     regular             new
# 3                           2         695.172598       promo             old
# 4                           2         515.630388     regular             old
# ...                       ...                ...         ...             ...
# 146075                      2         459.248827     regular             new
# 146076                      2         191.273227       promo             old
# 146077                      2         295.593448       promo             new
# 146078                      2         913.857221     regular             new
# 146079                      2         971.621577       promo             new
#
#         product_lvl_id1  customer_lvl_id1  location_lvl_id1  PERIOD_DT  \
# 0                 10084           1000000            100000 2022-07-04
# 1                 10084           1000000            100000 2022-07-04
# 2                 10084           1000000            100000 2022-07-04
# 3                 10084           1000000            100000 2022-07-04
# 4                 10084           1000000            100000 2022-07-04
# ...                 ...               ...               ...        ...
# 146075            10084           1000000            100000 2022-08-22
# 146076            10084           1000000            100000 2022-08-22
# 146077            10084           1000000            100000 2022-08-22
# 146078            10084           1000000            100000 2022-08-22
# 146079            10084           1000000            100000 2022-08-22
#
#        PERIOD_END_DT  VF_FORECAST_VALUE_REC
# 0         2022-07-10             216.295382
# 1         2022-07-10             182.582973
# 2         2022-07-10             210.741745
# 3         2022-07-10             237.245109
# 4         2022-07-10             175.971820
# ...              ...                    ...
# 146075    2022-08-28              70.561404
# 146076    2022-08-28              29.388224
# 146077    2022-08-28              45.416531
# 146078    2022-08-28             140.409827
# 146079    2022-08-28             149.285046
#
# [146080 rows x 13 columns]
