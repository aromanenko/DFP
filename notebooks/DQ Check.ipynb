# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt
nb_dir = Path.cwd()   
root = nb_dir.parent   
src_dir = root / 'src'
data_dir = root / 'data'

sys.path.append(str(src_dir))

from dq_checks import run, ib_dfp_read_dir, ib_dfp_ensure_required, ib_dfp_output_columns

# %%
res = run(str(data_dir))
res.head(20)
# Out:
#    PRODUCT_LVL_ID LOCATION_LVL_ID CUSTOMER_LVL_ID DISTR_CHANNEL_LVL_ID  \
# 0           80013          600006            None                 None
# 1           80033          600011            None                 None
# 2           80033          600012            None                 None
# 3           80005          600002            None                 None
# 4           80005          600004            None                 None
# 5           80005          600009            None                 None
# 6           80005          600010            None                 None
# 7           80005          600011            None                 None
# 8           80008          600002            None                 None
# 9           80008          600004            None                 None
# 10          80008          600005            None                 None
# 11          80008          600009            None                 None
# ...

# %%
d = ens(rd_dir(data_dir))
miss = [t for t in d.keys() if d[t].empty]

print('Всего таблиц в словаре:', len(d))
print('Пустые (либо реально пустые, либо отсутствовали как csv):')
miss
# Out:
# Всего таблиц в словаре: 20
# Пустые (либо реально пустые, либо отсутствовали как csv):
# ['DPS_ACC_AGG_HYBRID_FORECAST',
#  'DPS_DISTR_CHANNEL_ATTR',
#  'DPS_LOCATION_ATTR',
#  'DPS_LOCATION_LIFE',
#  'DPS_SELL_IN',
#  'DPS_PRODUCT_LIFE',
#  'DPS_PROMO_ATTR',
#  'DPS_SALES']

# %% [markdown]
# # Удобная табличная сводка

# %%
summary = (
    res.groupby(['WARNING_TYPE', 'INPUT_TABLE'])
       .size()
       .reset_index(name='CNT')
       .sort_values('CNT', ascending=False)
)

summary.head(10)
# Out:
#      WARNING_TYPE        INPUT_TABLE  CNT
# 3     MISSING_KEY          DPS_PRICE  120
# 4     MISSING_KEY        DPS_PRODUCT   62
# 0     MISSING_KEY       DPS_CUSTOMER   20
# 2     MISSING_KEY       DPS_LOCATION    4
# 5     MISSING_KEY          DPS_STOCK    2
# 1     MISSING_KEY  DPS_DISTR_CHANNEL    1
# 6  NEGATIVE_VALUE          DPS_STOCK    1

# %% [markdown]
# # Сколько проблем каждого типа

# %%
vc = res['WARNING_TYPE'].value_counts()

plt.figure()
vc.plot(kind='bar')
plt.title('Warnings by type')
plt.xlabel('WARNING_TYPE')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Топ таблиц, где больше всего проблем

# %%
vt = res['INPUT_TABLE'].value_counts().head(10)

plt.figure()
vt.plot(kind='bar')
plt.title('Top tables by warnings')
plt.xlabel('INPUT_TABLE')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
